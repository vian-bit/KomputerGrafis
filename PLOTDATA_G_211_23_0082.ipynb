# %% [markdown]
# <a href="https://colab.research.google.com/github/vian-bit/KomputerGrafis/blob/main/PLOTDATA_G_211_23_0082.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
DATAPLOT1
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,150,0,100])
plt.axis('on')
plt.grid(True)

#-----------define function y1 vs
x=np.arange(0,150,1)
y1=10+np.exp(.035*x)

#------------plot y1 vs x
plt.plot(x, y1,'b',label='y1')

#--------------plot the legend
plt.legend(loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""
DATAPLOT2
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,150,0,100])
plt.axis('on')
plt.grid(True)

#---------define data points
x=[20,40,60,80,100,120,140]
y1=[30,50,30,45,70,43,80]
y2=[45,35,40,60,60,55,70]

#-----------plot lines with labels
plt.plot(x,y1,'b',label='Temperature')
plt.plot(x,y2,'r',label='Pressure')

#-----------legend
plt.legend(loc='upper left')

#----------add makers
plt.scatter(x,y1,color='b',marker='s')
plt.scatter(x,y2,color='r',marker='*',s=50)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""
DATAPLOT3
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid(True)

t=[20,40,60,80,100,120,140] #----time
T=[30,33,37.5,44,55,70,86] #-------Temperature
p=[1.8,2.3,3,4,5.4,7.3,9.6] #-----Pressure

#---------plot T vs t in red on the left vertical
plt.plot(t,T,color='r',label='Temperature')
plt.xlabel('Time')
plt.ylabel('Temperature',color='r')
plt.tick_params(axis='y',labelcolor='r')
plt.legend(loc='upper left')

#--------plot P vs t in blue on the ringht vertical axis
plt.twinx()
plt.plot(t,p,color='b',label='Pressure')
plt.ylabel('Pressure', color='b')
plt.tick_params(axis='y', labelcolor='b')
plt.legend(loc='upper right')

#------title the plot
plt.title('Test Results')

plt.show()

# %%
"""
DATAPLOT4
"""

import matplotlib.pyplot as plt
import numpy as np


t=[0,20,40,60,80,100,120]
T=[28,30,35,43,55,70,85]
p=[1.8,2.3,3,4,5.4,7.3,9.6]

fig, ax1 = plt.subplots() #-----set up a plot ax1 with subplot

plt.grid(True) #--------draw grid

ax1.set_xlabel('Time (hrs)') #---label X axis of ax1

l1=plt.plot(t,T,'r',label='Temperature') #-------plot Temperature in red as curve l1

ax1.set_ylim([0,100]) #--set Y axis limits of ax1
ax1.set_ylabel(r'Temperature (° K)', color='r') #------label Y axis of ax1

ax2 = ax1.twinx() #-------set up ax2 as twin of ax1

l2=plt.plot(t,p, 'b',label='Pressure') #----plot pressure in blue as curve l2

ax2.set_ylim([0,10]) #---set Y axis limits of ax2
ax2.set_ylabel('Pressure (psi)', color='b') #--------label Y axis of ax2

line1,=plt.plot([1],label='Temperature',color='r') #----line 1 of legend
line2,=plt.plot([2],label='Pressure',color='b') #----line 2 of legend
plt.legend(handles=[line1,line2],loc='upper left') #----plot legend

plt.title('Test Data')
# Out:
# Text(0.5, 1.0, 'Test Data')

# %%
"""
DATAPLOT5
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid('True')

t=[20,40,60,80,100,120]
T=[30,35,43,55,70,85]
p=[2,3,4,5.3,7.3,9.6]
v=[.6,.58,.54,.46,.35,.2]

pp=[ ]
for i in np.arange(0,len(p),1):
  pp.append(p[i]*10)

vv=[ ]
for i in np.arange(0,len(v),1):
  vv.append(v[i]*100)

plt.plot(t,T,color='r',label='Temperature',marker='o')
plt.plot(t,pp,color='b',label='Pressure',marker='s')
plt.plot(t,vv,color='g',label='Volume',marker='d')
plt.legend(loc='upper left')

for y in np.arange(0,100+1,20):
      a=y/10
      a=str(a)
      plt.text(142,y,a,color='b')

plt.xlabel('time(hrs)')
plt.ylabel('temperature')
plt.text(151,65,'pressure(psi)',rotation=90,color='b')

for y in np.arange(100,-1,-20):
      a=y/100
      a=str(a)
      plt.text(162,y,a,color='g')
      plt.text(159,y,'-',color='g')

for y in np.arange(1,99,3):
      plt.text(157,y,'-',color='g')

plt.text(170,65,r'volume (cm3)',rotation=90,color='g')

plt.title('compression test results')

plt.show()

# %%
"""
REGRESSION1
"""

import matplotlib.pyplot as plt
import numpy as np

plt.axis([0,140,0,100])
plt.axis('on')
plt.grid('True')

t=[20,40,60,80,100,120]
T=[30,35,43,55,70,85]
p=[2,3,4,5.3,7.3,9.6]
v=[.6,.58,.54,.46,.35,.2]

pp=[ ]
for i in np.arange(0,len(p),1):
  pp.append(p[i]*10)

vv=[ ]
for i in np.arange(0,len(v),1):
  vv.append(v[i]*100)

plt.plot(t,T,color='r',label='Temperature',marker='o')
plt.plot(t,pp,color='b',label='Pressure',marker='s')
plt.plot(t,vv,color='g',label='Volume',marker='d')
plt.legend(loc='upper left')

for y in np.arange(0,100+1,20):
      a=y/10
      a=str(a)
      plt.text(142,y,a,color='b')

plt.xlabel('time(hrs)')
plt.ylabel('temperature')
plt.text(151,65,'pressure(psi)',rotation=90,color='b')

for y in np.arange(100,-1,-20):
      a=y/100
      a=str(a)
      plt.text(162,y,a,color='g')
      plt.text(159,y,'-',color='g')

for y in np.arange(1,99,3):
      plt.text(157,y,'-',color='g')

plt.text(170,65,r'volume (cm3)',rotation=90,color='g')

plt.title('compression test results')


n =len(v)

c1=np.sum(t)/n
c2=np.sum(v)/n
a=np.multiply(v,t)
c3=np.sum(a)
a=np.multiply(t,t)
c4=np.sum(a)

A=(c3-n*c1*c2)/(c4-n*c1*c1)
B=c2-A*c1

for tp in np.arange(t[0],t[5],2):
  vp=A*tp+B
  vp=vp*100
  plt.scatter(tp,vp,color='g',s=1)


sumee=0
for i in range(len(t)):
    e=(v[i]-(A*t[i]+B))
    ee=e*e
    sumee=sumee+ee
    rms=np.sqrt(sumee/n)


plt.text(60,28,'v=At+B',color='g')
plt.arrow(78,30,6,6,head_width=1.5,color='g',linewidth=5)

vp1=A*t[0]+B
vp1='%7.4f'%(vp1)
plt.text(2,64,vp1,color='g')

vp2=A*t[5]+B
vp2='%7.4f'%(vp2)
plt.text(122,25,vp2,color='g')

Ap='%7.5f'%(A)
plt.text(65,18,'A=',color='g')
plt.text(78,18,Ap,color='g')

Bp='%7.5f'%(B)
plt.text(65,12,'B=',color='g')
plt.text(73,12,Bp,color='g')

rms='%7.5f'%(A)
plt.text(95,3,'RMS error=',color='g')
plt.text(122,3,rms,color='g')

plt.show()
